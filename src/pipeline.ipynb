# %% [markdown]
# # 🍫 Building a Controlnet dataset with Fondant
#
# > ⚠️ Please note that this notebook **is not** compatible with **Google Colab**. To complete the tutorial, you must
# > initiate Docker containers. Starting Docker containers within Google Colab is not supported.
#
#
# ### Pipeline overview
#
#
# There are 5 components in total, these are:
#
# 1. [**Prompt Generation**](components/generate_prompts): This component generates a set of seed prompts using a rule-based approach that combines various rooms and styles together, like “a photo of a {room_type} in the style of {style_type}”. As input, it takes in a list of room types (bedroom, kitchen, laundry room, ..), a list of room styles (contemporary, minimalist, art deco, ...) and a list of prefixes (comfortable, luxurious, simple). These lists can be easily adapted to other domains. The output of this component is a list of seed prompts.
#
# 2. [**Image URL Retrieval**](https://github.com/ml6team/fondant/tree/main/components/prompt_based_laion_retrieval): This component retrieves images from the [LAION-5B](https://laion.ai/blog/laion-5b/) dataset based on the seed prompts. The retrieval itself is done based on CLIP embeddings similarity between the prompt sentences and the captions in the LAION dataset. This component doesn’t return the actual images yet, only the URLs. The next component in the pipeline will then download these images.
#
# 3. [**Download Images**](https://github.com/ml6team/fondant/tree/main/components/download_images): This component downloads the actual images based on the URLs retrieved by the previous component. It takes in the URLs as input and returns the actual images, along with some metadata (like their height and width).
#
# 4. [**Caption Filtering**] The LAION dataset contains a lot of low-quality captions, your task is to play around with filtering out captions that are either too long, too short, contain irrelevant data etc.
#
# 5. [**Conditioning Creation**] In this step your task is to write a component that creates a conditioning image from a given image. Unless you're running on GPU locally, it's adviced to stick to CPU-friendly transformations, like those found in [opencv](https://opencv.org/). Get creative and experiment!
#
# Here are some examples:
# - canny edges,
# - pixelation,
# - smoothed out hue, saturation, lightness, etc.
# - Hough maps
# - blob detection

# %% [markdown]
# ## Environment
#
# #### This section checks the prerequisites of your environment. Read any errors or warnings carefully.

# %% [markdown]
# **Ensure a Python between version 3.8 and 3.10 is available**

# %%
import sys
if sys.version_info < (3, 8, 0) or sys.version_info >= (3, 11, 0):
    raise Exception(f"A Python version between 3.8 and 3.10 is required. You are running {sys.version}")

# %% [markdown]
# **Check if docker compose is installed and the docker daemon is running**

# %%
# !docker compose version >/dev/null
# !docker info >/dev/null

# %% [markdown]
# **Make sure Fondant is installed**

# %%
# !pip install -r ../requirements.txt -q --disable-pip-version-check

# %% [markdown]
# ## Implement the pipeline
#
# ### Creating a pipeline
#
# First of all, we need to initialize the pipeline, which includes specifying a name for your pipeline, providing a description, and setting a base_path. The base_path is used to store the pipeline artifacts and data generated by the components.

# %%
from pathlib import Path

from fondant.pipeline import ComponentOp, Pipeline

BASE_PATH = "./data_dir"
Path(BASE_PATH).mkdir(parents=True, exist_ok=True)

pipeline = Pipeline(
    pipeline_name="controlnet-pipeline",
    pipeline_description="Pipeline that collects and processes data to train ControlNet",
    base_path=BASE_PATH
)

# %% [markdown]
# ### Adding a (custom) component

# %% [markdown]
# The first component of our pipeline is the `generate_prompts` component, which generates a set of prompts to query the LAION knn index with. This is a custom component implemented in this repository. You can find it at [./components/generate_prompts](./components/generate_prompts).
#
# To create an operation for a custom component, we create a `ComponentOp` and pass in the `component_dir` where the component is located.
#
# We can pass in arguments to change the behavior of the component. Here we are passing in `n_rows_to_load: 10`, which limits the amount of data that is generated for the purpose of this example.
#
# For an overview of the available arguments, you can check the [`fondant_component.yaml`](/edit/src/components/generate_prompts/fondant_component.yaml) specification.

# %%
generate_prompts_op = ComponentOp(
    component_dir="components/generate_prompts",
    arguments={
        "n_rows_to_load": 10,
    },
)

# %% [markdown]
# Once we've created an operation for our component, we can add it to our pipeline.

# %%
pipeline.add_op(generate_prompts_op)

# %% [markdown]
# Now, our pipeline consists of a single component that generates prompts.

# %% [markdown]
# ### Adding more (reusable) components
#
# We can now proceed to add more components.
#
# We will use some components available on the [Fondant Hub](https://fondant.ai/en/latest/components/hub/), for which we can create operations using the `ComponentOp.from_registry(...)` method.

# %%
# custom component
retrieval_component_op = ComponentOp(
    component_dir="components/prompt_based_laion_retrieval",
    arguments={
        "num_images": 2,
        "aesthetic_score": 9,
        "aesthetic_weight": 0.5,
        "url": "https://knn.laion.ai/knn-service"
    },
    cache=False
)


# reusable hub component
download_images_op = ComponentOp.from_registry(
    name="download_images",
    arguments={
        "timeout": 1,
        "retries": 0,
        "image_size": 512,
        "resize_mode": "center_crop",
        "resize_only_if_bigger": False,
        "min_image_size": 0,
        "max_aspect_ratio": 2.5,
    },
)

# custom component
filter_component_op = ComponentOp(
    component_dir="components/filter_component",
    arguments={
        "max_length": 100
    },
    cache=False
)

# custom component
conditioing_component_op = ComponentOp(
    component_dir="components/conditioning_component",
)

# %% [markdown]
# Now, we can use the components in our pipeline. We will chain them into a pipeline by defining dependencies between the different pipeline steps.

# %%
pipeline.add_op(retrieval_component_op, dependencies=generate_prompts_op)
pipeline.add_op(filter_component_op, dependencies=retrieval_component_op)
pipeline.add_op(download_images_op, dependencies=filter_component_op)
pipeline.add_op(conditioing_component_op, dependencies=download_images_op)

# %% [markdown]
# ## Writing the dataset to the Hugging Face Hub

# %% [markdown]
# To write the final dataset to HF hub, we will use the `write_to_hf_hub` component from the [Fondant Hub](https://fondant.ai/en/latest/components/hub/).
#
# You'll need a Hugging Face Hub account for this. If you don't have one, you can either create one, or skip this step.

# %%
USERNAME = "khaerens"
HF_TOKEN = "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"

# %% [markdown]
# `write_to_hf_hub` is a special type of reusable Fondant component which is **generic**. This means that it can handle different data schemas, but we have to tell it which schema to use.
#
# We do this by overwriting its `fondant_component.yaml` file with the schema of the data we want it to write. To achieve this, we can create a `fondant_component.yaml` file in the directory `components/write_to_hf_hub` with the following content:

# %%
# %%writefile components/write_to_hub_controlnet/fondant_component.yaml
# name: Write to hub
# description: Component that writes a dataset to the hub
# image: fndnt/write_to_hf_hub:0.6.2  # We use a docker image from the Fondant Hub instead of implementing our own.
#
# consumes:  # We fill in our data schema here. The component will write this data to the Hugging Face Hub.
#   images:
#     fields:
#       data:
#         type: binary
#
#   conditionings:
#     fields:
#       data:
#         type: binary
#
#   captions:
#     fields:
#       text:
#         type: string
#
# args:  # We repeat the arguments from the original `fondant_component.yaml`
#   hf_token:
#     description: The hugging face token used to write to the hub
#     type: str
#   username:
#     description: The username under which to upload the dataset
#     type: str
#   dataset_name:
#     description: The name of the dataset to upload
#     type: str
#   image_column_names:
#     description: A list containing the image column names. Used to format to image to HF hub format
#     type: list
#     default: []
#   column_name_mapping:
#     description: Mapping of the consumed fondant column names to the written hub column names
#     type: dict
#     default: {}
# Out:
# Overwriting components/write_to_hub_controlnet/fondant_component.yaml

# %% [markdown]
# For which we then create an operation as if it was a custom component:

# %%
write_to_hub_controlnet = ComponentOp(
    component_dir="components/write_to_hub_controlnet",
    arguments={
        "username": USERNAME ,
        "hf_token": HF_TOKEN ,
        "dataset_name": "controlnet-interior-design",
        "image_column_names": ["images_data", "conditionings_data", "captions_text"],
    },
)

# %% [markdown]
# And add it to the pipeline

# %%
pipeline.add_op(write_to_hub_controlnet, dependencies=conditioing_component_op)

# %% [markdown]
# ## Running the pipeline
#
# This pipeline will generate prompts, retrieve matching images in the laion dataset, download then and generate corresponding captions and segmentations. If you added the optional `write_to_hf_hub` component, it will write the resulting dataset to the HF hub.
#
# Fondant provides multiple runners to run our pipeline:
# - A Docker runner for local execution
# - A Vertex AI runner for managed execution on Google Cloud
# - A Kubeflow Pipelines runner for execution anywhere
#
# Here we will use the `DockerRunner` for local execution, which utilizes docker-compose under the hood.
#
# The runner will first build the custom component and download the reusable components from the component hub. Afterwards, you will see the components execute one by one.

# %%
# If you are using a MacBook with a M1 processor you have to make sure to set the docker default platform to linux/amd64
import os
os.environ["DOCKER_DEFAULT_PLATFORM"] = "linux/amd64"

# %%
from fondant.compiler import DockerCompiler
from fondant.runner import DockerRunner

from pathlib import Path

DockerCompiler().compile(pipeline=pipeline, output_path="docker-compose.yml")
DockerRunner().run("docker-compose.yml")
# Out:
# [2023-11-30 02:31:07,997 | fondant.compiler | INFO] Compiling controlnet-pipeline to docker-compose.yml
# [2023-11-30 02:31:07,997 | fondant.compiler | INFO] Base path found on local system, setting up ./data_dir as mount volume
# [2023-11-30 02:31:07,998 | fondant.pipeline | INFO] Sorting pipeline component graph topologically.
# [2023-11-30 02:31:08,063 | fondant.pipeline | INFO] All pipeline component specifications match.
# [2023-11-30 02:31:08,064 | fondant.compiler | INFO] Compiling service for generate_prompts
# [2023-11-30 02:31:08,065 | fondant.compiler | INFO] Found Dockerfile for generate_prompts, adding build step.
# [2023-11-30 02:31:08,065 | fondant.compiler | INFO] Compiling service for laion_retrieval
# [2023-11-30 02:31:08,067 | fondant.compiler | INFO] Found Dockerfile for laion_retrieval, adding build step.
# [2023-11-30 02:31:08,067 | fondant.compiler | INFO] Compiling service for filter_prompts
# [2023-11-30 02:31:08,068 | fondant.compiler | INFO] Found Dockerfile for filter_prompts, adding build step.
# [2023-11-30 02:31:08,069 | fondant.compiler | INFO] Compiling service for download_images
# [2023-11-30 02:31:08,070 | fondant.compiler | INFO] Compiling service for condition_images
# [2023-11-30 02:31:08,071 | fondant.compiler | INFO] Found Dockerfile for condition_images, adding build step.
# [2023-11-30 02:31:08,072 | fondant.compiler | INFO] Compiling service for write_to_hub
# [2023-11-30 02:31:08,090 | fondant.compiler | INFO] Successfully compiled to docker-compose.yml
#  write_to_hub Pulling
#  download_images Pulling
#  write_to_hub Pulled
#  download_images Pulled
# #0 building with "default" instance using docker driver
#
# #1 [generate_prompts internal] load .dockerignore
# #1 transferring context: 2B done
# #1 DONE 0.0s
#
# #2 [generate_prompts internal] load build definition from Dockerfile
# #2 transferring dockerfile: 538B done
# #2 DONE 0.0s
#
# #3 [generate_prompts internal] load metadata for docker.io/library/python:3.8-slim
# #3 DONE 0.0s
#
# #4 [generate_prompts 1/8] FROM docker.io/library/python:3.8-slim
# #4 DONE 0.0s
#
# #5 [generate_prompts internal] load build context
# #5 transferring context: 133B done
# #5 DONE 0.0s
#
# #6 [generate_prompts 2/8] RUN apt-get update &&     apt-get upgrade -y &&     apt-get install git -y
# #6 CACHED
#
# #7 [generate_prompts 4/8] RUN python3 -m pip install --upgrade pip
# #7 CACHED
#
# #8 [generate_prompts 7/8] COPY src/ .
# #8 CACHED
#
# #9 [generate_prompts 3/8] COPY requirements.txt /
# #9 CACHED
#
# #10 [generate_prompts 5/8] RUN pip3 install --no-cache-dir -r requirements.txt
# #10 CACHED
#
# #11 [generate_prompts 6/8] WORKDIR /component/src
# #11 CACHED
#
# #12 [generate_prompts 8/8] COPY fondant_component.yaml ../
# #12 CACHED
#
# #13 [generate_prompts] exporting to image
# #13 exporting layers done
# #13 writing image sha256:b5226f5d9e834a44f7975278f1d4c1c141da23649f97ed5c4c43f714333e2b87 done
# #13 naming to docker.io/library/controlnet-pipeline-generate_prompts done
# #13 DONE 0.0s
#
# #14 [laion_retrieval internal] load build definition from Dockerfile
# #14 transferring dockerfile: 574B done
# #14 DONE 0.0s
#
# #15 [laion_retrieval internal] load .dockerignore
# #15 transferring context: 2B done
# #15 DONE 0.0s
#
# #3 [laion_retrieval internal] load metadata for docker.io/library/python:3.8-slim
# #3 DONE 0.0s
#
# #4 [laion_retrieval 1/7] FROM docker.io/library/python:3.8-slim
# #4 DONE 0.0s
#
# #16 [laion_retrieval internal] load build context
# #16 transferring context: 159B done
# #16 DONE 0.0s
#
# #17 [laion_retrieval 3/7] COPY requirements.txt /
# #17 CACHED
#
# #18 [laion_retrieval 4/7] RUN pip3 install --no-cache-dir -r requirements.txt
# #18 CACHED
#
# #19 [laion_retrieval 6/7] WORKDIR /component/src
# #19 CACHED
#
# #6 [laion_retrieval 2/7] RUN apt-get update &&     apt-get upgrade -y &&     apt-get install git -y
# #6 CACHED
#
# #20 [laion_retrieval 5/7] RUN pip3 install fondant[aws,azure,gcp,component]==0.6.2
# #20 CACHED
#
# #21 [laion_retrieval 7/7] COPY src/ .
# #21 CACHED
#
# #22 [laion_retrieval] exporting to image
# #22 exporting layers done
# #22 writing image sha256:f044f4b5aa1c22243ff3639beeff32b97966de0c7265d4387ce6c6f903aa3a6e done
# #22 naming to docker.io/library/controlnet-pipeline-laion_retrieval done
# #22 DONE 0.0s
#
# #23 [filter_prompts internal] load .dockerignore
# #23 transferring context: 2B done
# #23 DONE 0.0s
#
# #24 [filter_prompts internal] load build definition from Dockerfile
# #24 transferring dockerfile: 621B done
# #24 DONE 0.0s
#
# #3 [filter_prompts internal] load metadata for docker.io/library/python:3.8-slim
# #3 DONE 0.0s
#
# #4 [filter_prompts 1/9] FROM docker.io/library/python:3.8-slim
# #4 DONE 0.0s
#
# #25 [filter_prompts internal] load build context
# #25 transferring context: 131B done
# #25 DONE 0.0s
#
# #26 [filter_prompts 4/9] RUN python3 -m pip install --upgrade pip
# #26 CACHED
#
# #27 [filter_prompts 7/9] WORKDIR /component/src
# #27 CACHED
#
# #6 [filter_prompts 2/9] RUN apt-get update &&     apt-get upgrade -y &&     apt-get install git -y
# #6 CACHED
#
# #28 [filter_prompts 3/9] COPY requirements.txt /
# #28 CACHED
#
# #29 [filter_prompts 6/9] RUN pip3 install fondant[aws,azure,gcp,component]==0.6.2
# #29 CACHED
#
# #30 [filter_prompts 5/9] RUN pip3 install --no-cache-dir -r requirements.txt
# #30 CACHED
#
# #31 [filter_prompts 8/9] COPY src/ .
# #31 CACHED
#
# #32 [filter_prompts 9/9] COPY fondant_component.yaml ../
# #32 CACHED
#
# #33 [filter_prompts] exporting to image
# #33 exporting layers done
# #33 writing image sha256:8e355c05a255d95e2fae2307a33a2ff391d6e6200be829369e754a1d861a08d1 done
# #33 naming to docker.io/library/controlnet-pipeline-filter_prompts done
# #33 DONE 0.0s
#
# #34 [condition_images internal] load .dockerignore
# #34 transferring context: 2B done
# #34 DONE 0.0s
#
# #35 [condition_images internal] load build definition from Dockerfile
# #35 transferring dockerfile: 621B done
# #35 DONE 0.0s
#
# #3 [condition_images internal] load metadata for docker.io/library/python:3.8-slim
# #3 DONE 0.0s
#
# #4 [condition_images 1/9] FROM docker.io/library/python:3.8-slim
# #4 DONE 0.0s
#
# #36 [condition_images internal] load build context
# #36 transferring context: 133B done
# #36 DONE 0.0s
#
# #37 [condition_images 7/9] WORKDIR /component/src
# #37 CACHED
#
# #38 [condition_images 6/9] RUN pip3 install fondant[aws,azure,gcp,component]==0.6.2
# #38 CACHED
#
# #6 [condition_images 2/9] RUN apt-get update &&     apt-get upgrade -y &&     apt-get install git -y
# #6 CACHED
#
# #39 [condition_images 5/9] RUN pip3 install --no-cache-dir -r requirements.txt
# #39 CACHED
#
# #40 [condition_images 8/9] COPY src/ .
# #40 CACHED
#
# #41 [condition_images 3/9] COPY requirements.txt /
# #41 CACHED
#
# #42 [condition_images 4/9] RUN python3 -m pip install --upgrade pip
# #42 CACHED
#
# #43 [condition_images 9/9] COPY fondant_component.yaml ../
# #43 CACHED
#
# #44 [condition_images] exporting to image
# #44 exporting layers done
# #44 writing image sha256:1c2faf97dce70f1cad3a702e947bbf2b5606347e8af245b6738adfb21fe8317e done
# #44 naming to docker.io/library/controlnet-pipeline-condition_images done
# #44 DONE 0.0s
#  Container controlnet-pipeline-generate_prompts-1  Recreate
#  Container controlnet-pipeline-generate_prompts-1  Recreated
#  Container controlnet-pipeline-laion_retrieval-1  Recreate
#  Container controlnet-pipeline-laion_retrieval-1  Recreated
#  Container controlnet-pipeline-filter_prompts-1  Recreate
#  Container controlnet-pipeline-filter_prompts-1  Recreated
#  Container controlnet-pipeline-download_images-1  Recreate
#  Container controlnet-pipeline-download_images-1  Recreated
#  Container controlnet-pipeline-condition_images-1  Recreate
#  Container controlnet-pipeline-condition_images-1  Recreated
#  Container controlnet-pipeline-write_to_hub-1  Recreate
#  Container controlnet-pipeline-write_to_hub-1  Recreated
# Attaching to controlnet-pipeline-condition_images-1, controlnet-pipeline-download_images-1, controlnet-pipeline-filter_prompts-1, controlnet-pipeline-generate_prompts-1, controlnet-pipeline-laion_retrieval-1, controlnet-pipeline-write_to_hub-1
# controlnet-pipeline-generate_prompts-1  | [2023-11-30 01:31:11,682 | fondant.cli | INFO] Component `GeneratePromptsComponent` found in module main
# controlnet-pipeline-generate_prompts-1  | [2023-11-30 01:31:11,690 | fondant.executor | INFO] Dask default local mode will be used for further executions.Our current supported options are limited to 'local' and 'default'.
# controlnet-pipeline-generate_prompts-1  | [2023-11-30 01:31:11,709 | fondant.executor | INFO] Matching execution detected for component. The last execution of the component originated from `controlnet-pipeline-20231130014353`.
# controlnet-pipeline-generate_prompts-1  | [2023-11-30 01:31:11,709 | fondant.executor | INFO] Skipping component execution
# controlnet-pipeline-generate_prompts-1  | [2023-11-30 01:31:11,710 | fondant.executor | INFO] Saving output manifest to /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/generate_prompts/manifest.json
# controlnet-pipeline-generate_prompts-1  | [2023-11-30 01:31:11,710 | fondant.executor | INFO] Writing cache key to /data_dir/controlnet-pipeline/cache/fbe4fc7feda1fd741302e3d34da138bb.txt
# controlnet-pipeline-generate_prompts-1 exited with code 0
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,497 | fondant.cli | INFO] Component `LAIONRetrievalComponent` found in module main
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,511 | fondant.executor | INFO] Dask default local mode will be used for further executions.Our current supported options are limited to 'local' and 'default'.
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,515 | fondant.executor | INFO] Caching disabled for the component
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,516 | root | INFO] Executing component
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,555 | fondant.data_io | INFO] Loading subset prompts with fields ['text']...
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,563 | fondant.data_io | INFO] The number of partitions of the input dataframe is 1. The available number of workers is 8.
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,564 | fondant.data_io | INFO] Repartitioning the data to 8 partitions before processing to maximize worker usage
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,564 | root | INFO] Columns of dataframe: ['prompts_text']
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,581 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/laion_retrieval/index
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,589 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/laion_retrieval/images
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,596 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/laion_retrieval/captions
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:13,596 | root | INFO] Writing data...
# [########################################] | 100% Completed | 1.81 sms
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:15,416 | fondant.executor | INFO] Saving output manifest to /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/laion_retrieval/manifest.json
# controlnet-pipeline-laion_retrieval-1   | [2023-11-30 01:31:15,416 | fondant.executor | INFO] Writing cache key to /data_dir/controlnet-pipeline/cache/f0fac4258b6bfa7d0b9a87504a83f845.txt
# controlnet-pipeline-laion_retrieval-1 exited with code 0
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,774 | fondant.cli | INFO] Component `FilterComponent` found in module main
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,792 | fondant.executor | INFO] Dask default local mode will be used for further executions.Our current supported options are limited to 'local' and 'default'.
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,802 | fondant.executor | INFO] Caching disabled for the component
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,802 | root | INFO] Executing component
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,881 | fondant.data_io | INFO] Loading subset images with fields ['url']...
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,905 | fondant.data_io | INFO] Loading subset captions with fields ['text']...
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,931 | root | INFO] Columns of dataframe: ['images_url', 'captions_text']
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,956 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/filter_prompts/index
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,965 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/filter_prompts/images
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,973 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/filter_prompts/captions
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:17,973 | root | INFO] Writing data...
# [########################################] | 100% Completed | 409.25 ms
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:18,394 | fondant.executor | INFO] Saving output manifest to /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/filter_prompts/manifest.json
# controlnet-pipeline-filter_prompts-1    | [2023-11-30 01:31:18,394 | fondant.executor | INFO] Writing cache key to /data_dir/controlnet-pipeline/cache/ed0ab64b7d4d7f4fd5b42d9e32832c97.txt
# controlnet-pipeline-filter_prompts-1 exited with code 0
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,657 | fondant.cli | INFO] Component `DownloadImagesComponent` found in module main
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,663 | fondant.executor | INFO] Dask default local mode will be used for further executions.Our current supported options are limited to 'local' and 'default'.
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,665 | fondant.executor | INFO] Previous component `filter_prompts` is not cached. Invalidating cache for current and subsequent components
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,665 | fondant.executor | INFO] Caching disabled for the component
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,665 | root | INFO] Executing component
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,732 | fondant.data_io | INFO] Loading subset images with fields ['url']...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,759 | root | INFO] Columns of dataframe: ['images_url']
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,777 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/download_images/index
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,786 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/download_images/images
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:21,786 | root | INFO] Writing data...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:24,767 | main | INFO] Downloading 0 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:24,782 | main | INFO] Downloading 2 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:24,787 | main | INFO] Downloading 66 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:24,936 | httpx | INFO] HTTP Request: GET https://i.pinimg.com/236x/ba/ff/8d/baff8df2192c5d2f81826751aa67d2b0.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:25,197 | httpx | INFO] HTTP Request: GET https://thumb7.shutterstock.com/image-photo/stock-vector-french-bulldog-450w-170068049.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:25,215 | main | INFO] Downloading 64 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,490 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,491 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,492 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,493 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,494 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,503 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,504 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,504 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,505 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,509 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,510 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,511 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,511 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,523 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,524 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,525 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,536 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,537 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,539 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,539 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,540 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,540 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,541 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,548 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,549 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,550 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,550 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,551 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,553 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,554 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,557 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,557 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,575 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,575 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,576 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,577 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,577 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,584 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,603 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,604 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,605 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,605 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,606 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,607 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,607 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,608 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,609 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,609 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,610 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,619 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,619 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,620 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,621 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,635 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,636 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,636 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,637 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,638 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,639 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,640 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,640 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,641 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,642 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,643 | httpx | INFO] HTTP Request: GET http://ih1.redbubble.net/image.212421213.4514/ra,classic_tee,x1000,f89f2b:1617e563f0,front-c,237,150,225,370-pad,220x294,ffffff.2u5.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,649 | httpx | INFO] HTTP Request: GET https://rlv.zcache.ca/bulldog_portrait_in_purple_haze_postcard-rafebb376e2bc4c68adb6f5f937f1d9dc_vgbaq_8byvr_324.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:26,651 | httpx | INFO] HTTP Request: GET https://rlv.zcache.de/malerei_eines_waldes_mit_fluss_briefmarke_top-r6eec437824194006b54a1c12afc21a10_v9i79_8byvr_324.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,158 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,159 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,165 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,165 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,167 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,174 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,181 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,190 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,194 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,204 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,207 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,223 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,225 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,228 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,250 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,253 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,254 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,261 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,274 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,274 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,309 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,347 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,367 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,379 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,400 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,433 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,436 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,468 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,474 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,476 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,480 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,506 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,564 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,593 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,602 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,614 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,637 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,640 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,644 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,703 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,789 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,811 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,818 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,845 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,850 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,852 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,853 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,855 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,857 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,858 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,858 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,860 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,862 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,862 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,864 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,870 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,874 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,879 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:27,981 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:28,148 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:28,150 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:28,151 | main | WARNING] Skipping https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg: ConnectTimeout('')
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:28,215 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:28,220 | httpx | INFO] HTTP Request: GET https://images-na.ssl-images-amazon.com/images/I/81F9EmOwoGL._AC_SL1500_.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:29,716 | main | INFO] Downloading 3 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:29,829 | httpx | INFO] HTTP Request: GET https://i.pinimg.com/236x/be/86/1e/be861e0242cd4a9a86c1d6f9aa00a999--painting-art-painting-prints.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:29,893 | httpx | INFO] HTTP Request: GET https://dplhqivlpbfks.cloudfront.net/box_resize/1220x1240/f245eecc-498888.png "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:29,939 | httpx | INFO] HTTP Request: GET https://img1.etsystatic.com/000/0/5329032/il_570xN.244835145.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:30,141 | main | INFO] Downloading 66 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,697 | httpx | INFO] HTTP Request: GET http://rlv.zcache.co.uk/holiday2_pet_clothes-r9baf99bfe5204e1189a500b48f09c6b3_v9i79_8byvr_324.jpg "HTTP/1.1 301 Moved Permanently"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,759 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,770 | httpx | INFO] HTTP Request: GET https://cdn.shopify.com/s/files/1/1982/1423/products/81p8Vt1hdzL._AC_SL1500_grande.jpg?v=1605940253 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,773 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,775 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,777 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,779 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,784 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# ...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,871 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,879 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,888 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,895 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,900 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,901 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,907 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,922 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,926 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:31,927 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,001 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,028 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,030 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,033 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,034 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,037 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,041 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,044 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,052 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,053 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,054 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,073 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,138 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,165 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,167 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,168 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,172 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,173 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,174 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,175 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,181 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,186 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,189 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,197 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,240 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,248 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,248 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,250 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,251 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,253 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,260 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,371 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,375 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,381 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,388 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,536 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,539 | httpx | INFO] HTTP Request: GET https://assets.bigcartel.com/product_images/255020072/Pet+Portrait.jpg?auto=format&fit=max&w=600 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:32,906 | httpx | INFO] HTTP Request: GET https://rlv.zcache.co.uk/holiday2_pet_clothes-r9baf99bfe5204e1189a500b48f09c6b3_v9i79_8byvr_324.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:33,606 | main | INFO] Downloading 3 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:33,750 | httpx | INFO] HTTP Request: GET https://i.icanvas.com/RAY1?d=3&sh=v&s=s&p=1&bg=w&t=1592766891 "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:33,786 | httpx | INFO] HTTP Request: GET https://www.paveikslai.lt/80006-large_default/suniukas.jpg "HTTP/1.1 301 Moved Permanently"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:33,798 | httpx | INFO] HTTP Request: GET https://static.wixstatic.com/media/3d64e8_8442f75576e74389b8552fa6fd8c0a4a~mv2.png/v1/fill/w_390,h_380,q_90/3d64e8_8442f75576e74389b8552fa6fd8c0a4a~mv2.png "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:33,945 | httpx | INFO] HTTP Request: GET https://paveikslai.lt/80006-large_default/suniukas.jpg "HTTP/1.1 200 OK"
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:34,063 | main | INFO] Downloading 1 images...
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:34,211 | httpx | INFO] HTTP Request: GET https://thumbs.dreamstime.com/b/hand-dragen-modeillustration-av-utkl%C3%A4tt-engelska-toy-terrier-i-f%C3%A4rger-vektor-75001099.jpg "HTTP/1.1 200 OK"
# [########################################] | 100% Completed | 12.65 s
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:34,897 | fondant.executor | INFO] Saving output manifest to /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/download_images/manifest.json
# controlnet-pipeline-download_images-1   | [2023-11-30 01:31:34,897 | fondant.executor | INFO] Writing cache key to /data_dir/controlnet-pipeline/cache/2f5b3ae9d0b06ce05c544feac812a00b.txt
# controlnet-pipeline-download_images-1 exited with code 0
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,231 | fondant.cli | INFO] Component `ConditioningComponent` found in module main
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,241 | fondant.executor | INFO] Dask default local mode will be used for further executions.Our current supported options are limited to 'local' and 'default'.
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,252 | fondant.executor | INFO] Previous component `download_images` is not cached. Invalidating cache for current and subsequent components
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,252 | fondant.executor | INFO] Caching disabled for the component
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,252 | root | INFO] Executing component
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,329 | fondant.data_io | INFO] Loading subset images with fields ['data']...
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,353 | root | INFO] Columns of dataframe: ['images_data']
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,378 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/condition_images/index
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,385 | root | INFO] Creating write task for: /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/condition_images/conditionings
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:37,385 | root | INFO] Writing data...
# [########################################] | 100% Completed | 19.47 ss
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:56,866 | fondant.executor | INFO] Saving output manifest to /data_dir/controlnet-pipeline/controlnet-pipeline-20231130023107/condition_images/manifest.json
# controlnet-pipeline-condition_images-1  | [2023-11-30 01:31:56,866 | fondant.executor | INFO] Writing cache key to /data_dir/controlnet-pipeline/cache/a18eda28c948a59afdb40d58979fbebc.txt
# controlnet-pipeline-condition_images-1 exited with code 0
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,448 | fondant.cli | INFO] Component `WriteToHubComponent` found in module main
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,452 | fondant.executor | INFO] Dask default local mode will be used for further executions.Our current supported options are limited to 'local' and 'default'.
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,456 | fondant.executor | INFO] Previous component `condition_images` is not cached. Invalidating cache for current and subsequent components
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,456 | fondant.executor | INFO] Caching disabled for the component
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,456 | root | INFO] Executing component
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,685 | main | INFO] Creating HF dataset repository under ID: 'khaerens/controlnet-interior-design'
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,880 | fondant.data_io | INFO] Loading subset images with fields ['data']...
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,904 | fondant.data_io | INFO] Loading subset conditionings with fields ['data']...
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,927 | fondant.data_io | INFO] Loading subset captions with fields ['text']...
# controlnet-pipeline-write_to_hub-1      | [2023-11-30 01:31:59,947 | root | INFO] Columns of dataframe: ['images_data', 'conditionings_data', 'captions_text']
# controlnet-pipeline-write_to_hub-1 exited with code 137

# %% [markdown]
# ## Exploring the dataset

# %% [markdown]
# You can also explore the dataset using the fondant explorer, this enables you to visualize your output dataset at each component step. Use the side panel on the left to browse through the steps and subsets.
#
# **If docker throws an error, run the command under next cell (this can happen if the previous container didn't shut down correctly)**

# %%
from fondant.explorer import run_explorer_app


run_explorer_app(
    base_path=BASE_PATH,
    container="fndnt/data_explorer",
    tag="0.6.2",
    port=8501,
)
# Out:
# [2023-11-30 01:38:18,885 | root | INFO] Using local base path: ./data_dir
# [2023-11-30 01:38:18,886 | root | INFO] This directory will be mounted to /artifacts in the container.
# [2023-11-30 01:38:18,887 | root | WARNING] You have not provided a credentials file. If you wish to access data from a cloud provider, mount the credentials file with the --credentials flag.
# [2023-11-30 01:38:18,887 | root | INFO] Running image from registry: fndnt/data_explorer with tag: 0.6.2 on port: 8501
# [2023-11-30 01:38:18,888 | root | INFO] Access the explorer at http://localhost:8501
# 0.6.2: Pulling from fndnt/data_explorer
# Digest: sha256:8f317b795798f24f37cb287355d6223c9cca94eb6f12e3535790d1faa79735ec
# Status: Image is up to date for fndnt/data_explorer:0.6.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb Cell 35 line 4
#       <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> from fondant.explorer import run_explorer_app
# ----> <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=3'>4</a> run_explorer_app(
#       <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=4'>5</a>     base_path=BASE_PATH,
#       <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=5'>6</a>     container="fndnt/data_explorer",
#       <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=6'>7</a>     tag="0.6.2",
#       <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a>     port=8501,
#       <a href='vscode-notebook-cell:/home/karel/Desktop/work/mlcon-workshop/src/pipeline.ipynb#X46sZmlsZQ%3D%3D?line=8'>9</a> )
#
# File ~/venvs/me_karel_Desktop_work_mlcon-workshop_src/lib/python3.10/site-packages/fondant/explorer.py:104, in run_explorer_app(base_path, port, container, tag, credentials)
#      99 logging.info(
#     100     f"Running image from registry: {container} with tag: {tag} on port: {port}",
#     101 )
#     102 logging.info(f"Access the explorer at http://localhost:{port}")
# --> 104 subprocess.call(cmd, stdout=subprocess.PIPE)
#
# File /usr/lib/python3.10/subprocess.py:347, in call(timeout, *popenargs, **kwargs)
#     345 with Popen(*popenargs, **kwargs) as p:
#     346     try:
# --> 347         return p.wait(timeout=timeout)
#     348     except:  # Including KeyboardInterrupt, wait handled that.
#     349         p.kill()
#
# File /usr/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File /usr/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %%
# !docker rm $(docker stop $(docker ps -a -q --filter ancestor=fndnt/data_explorer:0.6.2 --format="{{.ID}}"))
# Out:
# WARNING: Ignoring custom format, because both --format and --quiet are set.
# Error response from daemon: No such container: 90a4cf0d42f4

# %% [markdown]
# To stop the Explorer and continue the notebook, press the stop button at the top of the notebook.

# %% [markdown]
# ## Scaling up
#
# If you're happy with your dataset, it's time to scale up. Check [our documentation](https://fondant.ai/en/latest/pipeline/#compiling-and-running-a-pipeline) for more information about the available runners.
